# %%
# %matplotlib inline
from msslib.features import *
import matplotlib.pyplot as plt
from scipy.cluster import vq
from scipy import misc
import numpy as np

from msslib.prepare import *

# %%
win_size = 100
s_c = 400

# %%
img = misc.imread("/home/finlay/HMT/original_images/VenetusA/VA117RN-0118.jpg", flatten=True)

scaler = img_scaler((0.2,0.2))
img = scaler(img)[0]

#img = img[s_c:s_c+win_size,s_c:s_c+win_size]

plt.imshow(img, cmap='gray', interpolation='nearest')

# %%
f = np.fft.fft2(img)
f[:,5:] = 0

plt.imshow(np.real(np.fft.ifft2(f)), cmap='gray', interpolation='nearest')

# %%
aye = vq.whiten(img.flatten()).reshape((1000,1000))

# %%
plt.imshow(aye, cmap='gray', interpolation='nearest')

# %%
# Out:
# 0.071882576

# %%
n_img = std_dev_contrast_stretch(img)
plt.imshow(n_img, cmap='gray', interpolation='nearest')

# %%
weight = gaussian_weighter(n_img.shape)
g_img = weight(n_img)
plt.imshow(g_img, interpolation='nearest', cmap='gray')

# %%
g_img = weight(np.ones_like(img))
plt.imshow(g_img, interpolation='nearest', cmap='gray')

# %%
f_img = np.fft.fft2(g_img)
plt.imshow(np.real(f_img), interpolation='nearest')

# %%
f_img[:,10:] = 0

# %%
plt.imshow(np.real(np.fft.ifft2(f_img)), cmap='gray', interpolation='nearest')

# %%
f_img[0:10,0:10]

# %%
aye = np.asarray([[1,0],[0,1]])
plt.imshow(aye, cmap='gray', interpolation='nearest')

# %%
wit = np.fft.fft2(aye)
wit[:,1:] = 0
plt.imshow(np.real(wit), cmap='gray', interpolation='nearest')

# %%
plt.imshow(np.real(np.fft.ifft2(wit)), cmap='gray', interpolation='nearest')
