# %%
# %matplotlib inline

# %%
from scipy import misc
import matplotlib.pyplot as plt
from msslib.prepare import *
from msslib.evaluate import *
from msslib.utils import *
from msslib.features import *
from msslib.page_prima.page import PrimaPage
import itertools as it
import operator as op

from sklearn.metrics import confusion_matrix

# %%
original_image_path = "/home/finlay/HMT/original_images/VenetusA/VA117RN-0118.jpg"

label_path = "/home/finlay/HMT/data/VenetusA/region_img/VA117RN-0118.png"
page_path = "/home/finlay/HMT/data/VenetusA/region_xml/VA117RN-0118.xml"
image_path = "/home/finlay/Dropbox/rewritten_tests/M/VA117RN-0118.png"

opener = page_img_opener(PrimaPage(page_path))
scaler = img_scaler((0.2,0.2))

label, original_image = scaler(opener(label_path), opener(original_image_path))
image = misc.imread(image_path)

#original_image = to_greyscale(original_image)

# %%
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    #tick_marks = np.arange(len(iris.target_names))
    #plt.xticks(tick_marks, iris.target_names, rotation=45)
    #plt.yticks(tick_marks, iris.target_names)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cm = confusion_matrix(label.flatten(), image.flatten())
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
plot_confusion_matrix(cm_normalized)

# %%
b, g, r = original_image[:,:,0], original_image[:,:,1], original_image[:,:,2]

b = std_dev_contrast_stretch(b, 1)
g = std_dev_contrast_stretch(g, 1)
r = std_dev_contrast_stretch(r, 1)

aye = np.dstack((r,g,b))

# %%
misc.imsave('aye.png', aye)

# %%
plt.imshow(aye)
